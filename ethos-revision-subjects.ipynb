# %%
import pandas as pd

# %%
df = pd.read_csv('ethos/EThOS_CSV_202102.csv',names=["Title", "doi", "Author", "ISNI", "ORCID", "Institution", "Institution ISNI", "Date","Qualification", "Abstract", "Subject", "Supervisor", "Funder", "URL", "Repository URL" ])

# %%
df.head()
# Out:
#                                                Title  doi  \
# 0  Computation and measurement of turbulent flow ...  NaN
# 1  Prolactin and growth hormone secretion in norm...  NaN
# 2    Influence of strain fields on flame propagation  NaN
# 3  Connectivity, flow and transport in network mo...  NaN
# 4  The theory and implementation of a high qualit...  NaN
#
#                    Author                                    ISNI ORCID  \
# 0        Loizou, Panos A.  https://isni.org/isni/0000000136122593   NaN
# 1      Prescott, R. W. G.  https://isni.org/isni/0000000134992122   NaN
# 2  Mendes-Lopes, J. M. C.  https://isni.org/isni/0000000133937105   NaN
# 3   Robinson, Peter Clive  https://isni.org/isni/0000000135292822   NaN
# 4            Lower, K. N.  https://isni.org/isni/0000000136133567   NaN
#
#                          Institution                        Institution ISNI  \
# 0           University of Manchester  https://isni.org/isni/0000000121662407
# 1  University of Newcastle upon Tyne  https://isni.org/isni/0000000104627212
# 2            University of Cambridge  https://isni.org/isni/0000000121885934
# 3               University of Oxford  https://isni.org/isni/0000000419368948
# 4              University of Bristol  https://isni.org/isni/0000000419367603
#
#      Date   Qualification                                           Abstract  \
# 0  1989.0  Thesis (Ph.D.)                                                NaN
# 1  1983.0  Thesis (Ph.D.)                                                NaN
# 2  1983.0  Thesis (Ph.D.)  Flame propagation can be highly influenced by ...
# 3  1984.0  Thesis (Ph.D.)  In order to evaluate the safety of radioactive...
# 4  1985.0  Thesis (Ph.D.)                                                NaN
#
#                     Subject Supervisor Funder  \
# 0         Physical Sciences        NaN    NaN
# 1       Biological Sciences        NaN    NaN
# 2  Engineering & Technology        NaN    NaN
# 3         Physical Sciences  Rae, John    NaN
# 4  Engineering & Technology        NaN    NaN
#
#                                                  URL  \
# 0  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 1  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 2  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 3  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 4  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
#
#                                       Repository URL
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  http://ora.ox.ac.uk/objects/uuid:c61bf73b-b794...
# 4                                                NaN

# %%
df_2015_2020 = df[df.Date >= 2015]

# %%
df_2015_2020.head()
# Out:
#                                                     Title  doi  \
# 8265                              Sub-versions of reading  NaN
# 9034    Trade unions and the restructuring of working ...  NaN
# 9046    Preparing students for citizenship? : civic ed...  NaN
# 35236   Experiencing civil society : the reality of ci...  NaN
# 152297  Computer simulation of conformational change i...  NaN
#
#                                Author                                    ISNI  \
# 8265                    Littau, Karin  https://isni.org/isni/0000000136109786
# 9034            Cornell, Judith Emily  https://isni.org/isni/0000000135628349
# 9046            Tse, Thomas Kwan-choi  https://isni.org/isni/0000000136032328
# 35236              Hodgson, Lesley C.  https://isni.org/isni/0000000135798495
# 152297  Phillips, Stephen Christopher  https://isni.org/isni/0000000134894661
#
#                                      ORCID                Institution  \
# 8265                                   NaN      University of Warwick
# 9034                                   NaN      University of Warwick
# 9046                                   NaN      University of Warwick
# 35236                                  NaN  University of South Wales
# 152297  https://orcid.org/0000000279010839  University of Southampton
#
#                               Institution ISNI    Date   Qualification  \
# 8265    https://isni.org/isni/0000000088091613  2018.0  Thesis (Ph.D.)
# 9034    https://isni.org/isni/0000000088091613  2018.0  Thesis (Ph.D.)
# 9046    https://isni.org/isni/0000000088091613  2018.0  Thesis (Ph.D.)
# 35236   https://isni.org/isni/0000000459072711  2017.0  Thesis (Ph.D.)
# 152297  https://isni.org/isni/0000000419369297  2015.0  Thesis (Ph.D.)
#
#                                                  Abstract  \
# 8265    My PhD is entitled Sub-Versions of Reading. Th...
# 9034    Health care is an unusual issue for collective...
# 9046    Situated in the post-war socio-political milie...
# 35236   Discussions about civil society have tradition...
# 152297  A new method for modifying the course of a mol...
#
#                                      Subject Supervisor  \
# 8265                   Language & Literature        NaN
# 9034    Social, Economic & Political Studies        NaN
# 9046                               Education        NaN
# 35236   Social, Economic & Political Studies        NaN
# 152297                     Physical Sciences        NaN
#
#                                                    Funder  \
# 8265                                                  NaN
# 9034    South African Medical Research Council ; Forei...
# 9046                                                  NaN
# 35236                                                 NaN
# 152297                                                NaN
#
#                                                       URL  \
# 8265    https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 9034    https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 9046    https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 35236   https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 152297  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
#
#                                            Repository URL
# 8265                    http://wrap.warwick.ac.uk/104941/
# 9034                    http://wrap.warwick.ac.uk/104943/
# 9046                    http://wrap.warwick.ac.uk/104947/
# 35236   https://pure.southwales.ac.uk/en/studentthesis...
# 152297                https://eprints.soton.ac.uk/373628/

# %%
data = df_2015_2020

# %%
m = data[data['Abstract'].str.contains(" CER ", na=False)]

# %%
m.head()
# Out:
#                                                     Title  doi  \
# 550547  Molecular simulations of model bilayers of ski...  NaN
# 567275  Corporate environmental responsibility in Russ...  NaN
# 567794  Motivations for Corporate Environmental Respon...  NaN
#
#                           Author ISNI ORCID             Institution  \
# 550547            O'Neill, D. W.  NaN   NaN   University of Warwick
# 567275         Lonsdale, Nadezda  NaN   NaN  University of Brighton
# 567794  McDonogh, Thomas Antonio  NaN   NaN       Durham University
#
#                               Institution ISNI    Date    Qualification  \
# 550547  https://isni.org/isni/0000000088091613  2019.0   Thesis (Ph.D.)
# 567275  https://isni.org/isni/0000000121073784  2020.0   Thesis (Ph.D.)
# 567794  https://isni.org/isni/0000000087000572  2020.0  Thesis (D.B.A.)
#
#                                                  Abstract Subject Supervisor  \
# 550547  The lipid matrix within the SC is believed to ...     NaN        NaN
# 567275  The Russian oil industry is responsible for su...     NaN        NaN
# 567794  This study identifies the determinants of corp...     NaN        NaN
#
#                                                    Funder  \
# 550547  Engineering and Physical Sciences Research Cou...
# 567275                                                NaN
# 567794                                                NaN
#
#                                                       URL  \
# 550547  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 567275  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
# 567794  https://ethos.bl.uk/OrderDetails.do?uin=uk.bl....
#
#                                            Repository URL
# 550547                  http://wrap.warwick.ac.uk/133220/
# 567275  https://research.brighton.ac.uk/en/studentThes...
# 567794                    http://etheses.dur.ac.uk/13778/

# %%
m.count()
# Out:
# Title               3
# doi                 0
# Author              3
# ISNI                0
# ORCID               0
# Institution         3
# Institution ISNI    3
# Date                3
# Qualification       3
# Abstract            3
# Subject             0
# Supervisor          0
# Funder              1
# URL                 3
# Repository URL      3
# dtype: int64

# %%
m["Subject"]
# Out:
# 550547    NaN
# 567275    NaN
# 567794    NaN
# Name: Subject, dtype: object

# %%
m["Repository URL"]
# Out:
# 394523    https://www.research.manchester.ac.uk/portal/e...
# 397228       https://discovery.ucl.ac.uk/id/eprint/1461109/
# 399424                   https://doi.org/10.17863/CAM.16619
# 406188                     http://hdl.handle.net/1842/10487
# 414363        http://livrepository.liverpool.ac.uk/2007403/
#                                 ...
# 565702    https://www.research.manchester.ac.uk/portal/e...
# 567275    https://research.brighton.ac.uk/en/studentThes...
# 567794                      http://etheses.dur.ac.uk/13778/
# 568849                    https://doi.org/10.17638/03103898
# 570645           http://etheses.bham.ac.uk//id/eprint/9679/
# Name: Repository URL, Length: 137, dtype: object
